# %% [markdown]
# <a href="https://colab.research.google.com/github/iaagulo/Machine-Learning-Basics/blob/main/Ch04_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Neural Networks**

# %% [markdown]
# ##**4.1 Why Study Neural Networks**

# %% [markdown]
# ##**4.2 Display the Image File**

# %% [markdown]
# ####**4.2.1 Importing the Modules**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ####**4.2.2 Importing the Image Files**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/'Colab Notebooks'/Book
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Book

# %%
ls
# Out:
# carbig.csv                            Ch04_Neural_Networks.ipynb
# Ch01_Intro_to_Machine_Learning.ipynb  Figures/
# Ch02_Gradient_Descent.ipynb           PCT01.ipynb
# Ch02_MultivariateLR.ipynb             PCT01_Solution.ipynb

# %% [markdown]
# ####**4.2.3 Displaying the Image File**

# %%
im = plt.imread('Figures/flower.jpeg')
plt.imshow(im)

# %%
# Red Layer
plt.imshow(im[:,:,0])

# %%
# Green Layer
plt.imshow(im[:,:,1])

# %%
# Blue Layer
plt.imshow(im[:,:,2])

# %%
im = plt.imread('Figures/mango.jpeg')
plt.imshow(im)

# %%
# Red Layer
plt.imshow(im[:,:,0])

# %%
# Green Layer
plt.imshow(im[:,:,1])

# %%
# Blue Layer
plt.imshow(im[:,:,2])
